# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
data = pd.read_csv("Data/full_dat.csv", index_col=[0,1])
data.dropna(inplace=True)

# %%
data.head()
# Out:
#              iso3 ISO-alpha3 Code Region Name Sub-region Name  \
# Country Year
# Austria 2006  AUT             AUT      Europe  Western Europe
#         2008  AUT             AUT      Europe  Western Europe
#         2010  AUT             AUT      Europe  Western Europe
#         2011  AUT             AUT      Europe  Western Europe
#         2012  AUT             AUT      Europe  Western Europe
#
#              Developed / Developing Countries  Session  \
# Country Year
# Austria 2006                        Developed       61
#         2008                        Developed       63
#         2010                        Developed       65
#         2011                        Developed       66
#         2012                        Developed       67
#
#                                                          Speech    neg    neu  \
# Country Year
# Austria 2006  “United in diversity”: \nthis motto of the Eur...  0.074  0.743
#         2008  These days, on our \ntelevision screens, image...  0.078  0.683
#         2010  The tragic \nearthquake in Haiti, the devastat...  0.060  0.698
#         2011  This year has once \nagain confirmed the impor...  0.063  0.723
#         2012  The events of recent\nmonths have illustrated ...  0.094  0.693
#
#                 pos  Life Ladder  Log GDP per capita  Social support  \
# Country Year
# Austria 2006  0.183     7.122211           10.841940        0.936350
#         2008  0.239     7.180954           10.886662        0.934593
#         2010  0.242     7.302679           10.861471        0.914193
#         2011  0.214     7.470513           10.886909        0.944157
#         2012  0.213     7.400689           10.889132        0.945142
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country Year
# Austria 2006                         70.760002                      0.941382
#         2008                         71.080002                      0.879069
#         2010                         71.400002                      0.895980
#         2011                         71.540001                      0.939356
#         2012                         71.680000                      0.919704
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country Year
# Austria 2006    0.302386                   0.490111         0.823105
#         2008    0.291309                   0.613625         0.832170
#         2010    0.130891                   0.546145         0.814719
#         2011    0.131578                   0.702721         0.789471
#         2012    0.117804                   0.770586         0.822248
#
#               Negative affect
# Country Year
# Austria 2006         0.173812
#         2008         0.173195
#         2010         0.155793
#         2011         0.145238
#         2012         0.156675

# %%
def plot_country_values(country_name, x_val, y_val):
    plt.scatter(data.loc[(country_name)][x_val], data.loc[(country_name)][y_val])
    
    
plot_country_values("Netherlands", "Life Ladder", "pos")

# %%
def plot_country_values(country_name, x_val, y_val):
    plt.scatter(data[x_val].values, data[y_val].values)
    
    
plot_country_values("Netherlands", "Life Ladder", "pos")

# %%
sent_columns = ['neg', 'neu', 'pos']
happy_columns = ['Life Ladder', 'Log GDP per capita', 'Social support', 'Healthy life expectancy at birth', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Positive affect', 'Negative affect']
sub = data[sent_columns + happy_columns]
cor = sub.corr()

# %%
cor
# Out:
#                                        neg       neu       pos  Life Ladder  \
# neg                               1.000000 -0.574582 -0.238366     0.152778
# neu                              -0.574582  1.000000 -0.657796    -0.204821
# pos                              -0.238366 -0.657796  1.000000     0.102070
# Life Ladder                       0.152778 -0.204821  0.102070     1.000000
# Log GDP per capita                0.147823 -0.188121  0.086849     0.792053
# Social support                    0.094645 -0.108554  0.041915     0.710937
# Healthy life expectancy at birth  0.125701 -0.159669  0.073800     0.751063
# Freedom to make life choices     -0.001621 -0.057145  0.069450     0.549184
# Generosity                       -0.024278 -0.100815  0.141703     0.209148
# Perceptions of corruption        -0.020437  0.080444 -0.076407    -0.466112
# Positive affect                   0.013357 -0.066926  0.066960     0.537622
# Negative affect                   0.035710  0.022396 -0.059396    -0.292365
#
#                                   Log GDP per capita  Social support  \
# neg                                         0.147823        0.094645
# neu                                        -0.188121       -0.108554
# pos                                         0.086849        0.041915
# Life Ladder                                 0.792053        0.710937
# Log GDP per capita                          1.000000        0.711518
# Social support                              0.711518        1.000000
# Healthy life expectancy at birth            0.855113        0.626078
# Freedom to make life choices                0.384608        0.430114
# Generosity                                 -0.013313        0.079411
# Perceptions of corruption                  -0.352743       -0.237564
# Positive affect                             0.293796        0.433023
# Negative affect                            -0.200272       -0.379378
#
#                                   Healthy life expectancy at birth  \
# neg                                                       0.125701
# neu                                                      -0.159669
# pos                                                       0.073800
# Life Ladder                                               0.751063
# Log GDP per capita                                        0.855113
# Social support                                            0.626078
# Healthy life expectancy at birth                          1.000000
# Freedom to make life choices                              0.406857
# Generosity                                                0.012941
# Perceptions of corruption                                -0.332593
# Positive affect                                           0.331901
# Negative affect                                          -0.138410
#
#                                   Freedom to make life choices  Generosity  \
# neg                                                  -0.001621   -0.024278
# neu                                                  -0.057145   -0.100815
# pos                                                   0.069450    0.141703
# Life Ladder                                           0.549184    0.209148
# Log GDP per capita                                    0.384608   -0.013313
# Social support                                        0.430114    0.079411
# Healthy life expectancy at birth                      0.406857    0.012941
# Freedom to make life choices                          1.000000    0.328011
# Generosity                                            0.328011    1.000000
# Perceptions of corruption                            -0.495006   -0.252683
# Positive affect                                       0.619393    0.361130
# Negative affect                                      -0.284942   -0.101441
#
#                                   Perceptions of corruption  Positive affect  \
# neg                                               -0.020437         0.013357
# neu                                                0.080444        -0.066926
# pos                                               -0.076407         0.066960
# Life Ladder                                       -0.466112         0.537622
# Log GDP per capita                                -0.352743         0.293796
# Social support                                    -0.237564         0.433023
# Healthy life expectancy at birth                  -0.332593         0.331901
# Freedom to make life choices                      -0.495006         0.619393
# Generosity                                        -0.252683         0.361130
# Perceptions of corruption                          1.000000        -0.297683
# Positive affect                                   -0.297683         1.000000
# Negative affect                                    0.311531        -0.371691
#
#                                   Negative affect
# neg                                      0.035710
# neu                                      0.022396
# pos                                     -0.059396
# Life Ladder                             -0.292365
# Log GDP per capita                      -0.200272
# Social support                          -0.379378
# Healthy life expectancy at birth        -0.138410
# Freedom to make life choices            -0.284942
# Generosity                              -0.101441
# Perceptions of corruption                0.311531
# Positive affect                         -0.371691
# Negative affect                          1.000000

# %%
cor_sub = cor.drop(sent_columns)
cor_sub = cor_sub.drop(happy_columns, axis=1)
cor_sub
# Out:
#                                        neg       neu       pos
# Life Ladder                       0.152778 -0.204821  0.102070
# Log GDP per capita                0.147823 -0.188121  0.086849
# Social support                    0.094645 -0.108554  0.041915
# Healthy life expectancy at birth  0.125701 -0.159669  0.073800
# Freedom to make life choices     -0.001621 -0.057145  0.069450
# Generosity                       -0.024278 -0.100815  0.141703
# Perceptions of corruption        -0.020437  0.080444 -0.076407
# Positive affect                   0.013357 -0.066926  0.066960
# Negative affect                   0.035710  0.022396 -0.059396

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = cor_sub
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
country_name = "Netherlands"

X = data.loc[country_name][happy_columns].to_numpy()
y = data.loc[country_name]['pos'].to_numpy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)
reg.score(X, y)
# Out:
# 0.3862580165428753

# %%
reg.score(X_test, y_test)
# Out:
# -4.06658338984374
